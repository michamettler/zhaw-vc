# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
import json
# Out:
# WARNING:tensorflow:From c:\Workarea\Projects\zhaw\zhaw-vc\.venv\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
img1_path = 'ressource/fiennes2.png'

img1 = cv2.imread(img1_path)

plt.imshow(img1[:,:,::-1])
plt.show()

# %%
demography = DeepFace.analyze(img1_path, actions = ['emotion', 'age', 'gender', 'race'])
demography
# Out:
# Action: race: 100%|██████████| 4/4 [00:06<00:00,  1.66s/it]
# [{'emotion': {'angry': np.float32(4.6745853),
#    'disgust': np.float32(0.0013602634),
#    'fear': np.float32(21.274538),
#    'happy': np.float32(28.58864),
#    'sad': np.float32(2.2603357),
#    'surprise': np.float32(0.4744765),
#    'neutral': np.float32(42.726067)},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 295,
#    'y': 118,
#    'w': 268,
#    'h': 268,
#    'left_eye': (455, 213),
#    'right_eye': (376, 236)},
#   'face_confidence': np.float64(0.94),
#   'age': 46,
#   'gender': {'Woman': np.float32(9.719563e-05), 'Man': np.float32(99.99991)},
#   'dominant_gender': 'Man',
#   'race': {'asian': np.float32(0.00055258017),
#    'indian': np.float32(0.009805157),
#    'black': np.float32(0.00013236981),
#    'white': np.float32(90.13694),
#    'middle eastern': np.float32(8.071717),
#    'latino hispanic': np.float32(1.7808546)},
#   'dominant_race': 'white'}]
